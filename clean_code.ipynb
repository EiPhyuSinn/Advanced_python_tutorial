# %%
# Docstring -> describe functions/ inputs/ outputs
def add(a: int, b: int) -> int:
    """
    Add two integers and return the result.

    Args:
        a (int): First number
        b (int): Second number

    Returns:
        int: Sum of a and b
    """
    return a + b


# Type Hints
a : list[str] = ['apple', 'banana', 'cherry']
b : dict[str,int] = {'apple': 1, 'banana': 2}
c : tuple[int] = (1, 2, 3)
d : set[float] = {1.0, 2.0, 3.0}
print(a,b,c,d)

# PEP 8 - Style Guide
# https://peps.python.org/pep-0008/

# Naming rules 
MAX_VALUE = 100  # Constant variable in uppercase
def calculate_area(radius: float) -> float:  # Function name in lowercase with underscores
    pi = 3.14159  # Local variable in lowercase
    return pi * radius ** 2
# Out:
# ['apple', 'banana', 'cherry'] {'apple': 1, 'banana': 2} (1, 2, 3) {1.0, 2.0, 3.0}
