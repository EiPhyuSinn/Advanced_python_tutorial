# %%
# Try/except 

class customError(Exception):
     pass
    
try:
    value = int(input('Enter a value to divide 10 by: '))
    result = 10/value 
    if value == 13:
            raise customError('Unlucky number 13!')
except ValueError:
    print('Not a value')
except ZeroDivisionError:
    print('You cannot divide by zero')
except customError as e:
    print(f'Custom error: {e}')
except Exception as e:
    print(f'An unexpected error occurred: {e}')
else: 
    print(f'The result is {result}')
finally: 
    print('Closing the progam')
# Out:
# Custom error: Unlucky number 13!
# Closing the progam
